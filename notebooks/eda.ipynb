# %% [markdown]
# # EDA & Ablations
# Use this notebook to explore the synthetic dataset and run small ablations.

# %%
from gnn_credit_fraud.data.simulate import generate_synthetic
generate_synthetic('data/simulated', seed=42, n_borrowers=1000)
print('Done')
